# %%
import numpy as np
2*np.array([33, 20])
# Out:
# array([66, 40])

# %%
x= np.array([33, 20])//1
x
# Out:
# array([33, 20])

# %%
type(x[0])
# Out:
# numpy.float64

# %%
x.astype('int')
# Out:
# array([29, 18])

# %%
y = [2, 11]

# %%
np.array(y)
# Out:
# array([ 2, 11])
