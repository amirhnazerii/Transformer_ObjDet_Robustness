# %%
A = [1 , 2 , 4, 6 , 7]


dict(list(enumerate(A)))
# Out:
# {0: 1, 1: 2, 2: 4, 3: 6, 4: 7}

# %%
list(enumerate(A))
# Out:
# [(0, 1), (1, 2), (2, 4), (3, 6), (4, 7)]

# %%
import torch
img_tensors_loaded= torch.load("/scratch/anazeri/new_attack/coco/img_tensorsDETRr50dc5_imgs1.pt")
img_tensors_loaded
# Out:
# [tensor([[[ 0.8095,  0.8191,  0.8624,  ..., -0.9444, -0.9520, -0.9146],
#           [ 0.7867,  0.7696,  0.8270,  ..., -0.9792, -0.9499, -0.9606],
#           [ 0.7831,  0.7637,  0.8114,  ..., -0.9263, -0.9342, -0.9400],
#           ...,
#           [ 1.0553,  0.9189,  0.9701,  ...,  0.6685,  0.7706,  0.2177],
#           [ 1.0408,  1.0637,  0.9963,  ...,  0.3373,  0.0978,  0.1834],
#           [ 0.7758,  1.0327,  1.0670,  ..., -0.1297, -0.1169, -0.2482]],
#
#          [[ 0.5151,  0.5512,  0.6577,  ..., -0.5968, -0.6822, -0.6694],
#           [ 0.4949,  0.4992,  0.6084,  ..., -0.6731, -0.6663, -0.6805],
#           [ 0.5275,  0.5177,  0.6141,  ..., -0.5728, -0.7170, -0.6684],
#           ...,
#           [ 1.3028,  1.2586,  1.0027,  ...,  0.2911, -0.3013, -0.3693],
#           [ 1.3073,  1.2506,  1.0539,  ..., -0.2090, -0.5772, -0.2878],
#           [ 0.9231,  1.2803,  1.2219,  ..., -0.6663, -0.4844, -0.9830]],
#
# ...
